# %%
import pandas as pd

file_path = "Schreibmaschinen.csv"

# %%
# Erstmal mit Latin1 (ISO-8859-1), oft Standard bei Windows/Excel
schreibmaschienen_df = pd.read_csv(file_path, encoding="cp1252", sep=";")

# %%
# Überblick
print(schreibmaschienen_df.shape)
print(schreibmaschienen_df.columns)
schreibmaschienen_df.head()
# Out:
# (125, 84)
# Index(['LabelSeiteOrganisation', 'LabelSeiteSeite', 'LabelSeiteDatum',
#        'LabelSeiteSeiten', 't1', 'T2', 'T21', 'T31', 'T22', 'T32', 'T23',
#        'T33', 'T24', 'T34', 'T25', 'T35', 'T16', 'T26', 'T36', 'T17', 'T27',
#        'T37', 'T18', 'T28', 'T38', 'T19', 'T29', 'T39', 'T20', 'T30', 'T40',
#        'TH1', 'TH11', 'TH21', 'TH31', 'TH2', 'TH12', 'TH22', 'TH32', 'TH3',
#        'TH13', 'TH23', 'TH33', 'TH4', 'TH14', 'TH24', 'TH34', 'TH5', 'TH15',
#        'TH25', 'TH35', 'TH6', 'TH16', 'TH26', 'TH36', 'TH7', 'TH17', 'TH27',
#        'TH37', 'TH8', 'TH18', 'TH28', 'TH38', 'TH9', 'TH19', 'TH29', 'TH39',
#        'TH10', 'TH20', 'TH30', 'TH40', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8',
#        'T9', 'T10', 't11', 't12', 'T13', 'T14', 'T15'],
#       dtype='object')
#    LabelSeiteOrganisation  LabelSeiteSeite  LabelSeiteDatum  LabelSeiteSeiten  \
# 0                     NaN              NaN              NaN               NaN
# 1                     NaN              NaN              NaN               NaN
# 2                     NaN              NaN              NaN               NaN
# 3                     NaN              NaN              NaN               NaN
# 4                     NaN              NaN              NaN               NaN
#
#               t1                                         T2  T21  T31  T22  \
# 0  1/2024/0501 0  Mercedes BŸromaschinenwerke AG\nunbekannt  NaN  NaN  NaN
# 1  1/2024/0501 0  Mercedes BŸromaschinenwerke AG\nunbekannt  NaN  NaN  NaN
# 2  1/2024/0501 0  Mercedes BŸromaschinenwerke AG\nunbekannt  NaN  NaN  NaN
# 3  1/2024/0501 0  Mercedes BŸromaschinenwerke AG\nunbekannt  NaN  NaN  NaN
# 4  1/2024/0501 0  Mercedes BŸromaschinenwerke AG\nunbekannt  NaN  NaN  NaN
#
#    T32  ...  T6  T7                       T8  T9  T10  t11  t12  \
# 0  NaN  ... NaN NaN  RZ 7.1.KTD EG S 53.B 02 NaN  NaN  NaN  NaN
# 1  NaN  ... NaN NaN  RZ 7.1.KTD EG S 53.B 02 NaN  NaN  NaN  NaN
# 2  NaN  ... NaN NaN  RZ 7.1.KTD EG S 53.B 02 NaN  NaN  NaN  NaN
# 3  NaN  ... NaN NaN  RZ 7.1.KTD EG S 53.B 02 NaN  NaN  NaN  NaN
# 4  NaN  ... NaN NaN  RZ 7.1.KTD EG S 53.B 02 NaN  NaN  NaN  NaN
#
#                                                  T13  \
# 0  \\dtmbgw2\museumplus\Objektbilder\verknŸpft\20...
# 1  \\dtmbgw2\museumplus\Objektbilder\verknŸpft\20...
# 2  \\dtmbgw2\museumplus\Objektbilder\verknŸpft\20...
# 3  \\dtmbgw2\museumplus\Objektbilder\verknŸpft\20...
# 4  \\dtmbgw2\museumplus\Objektbilder\verknŸpft\20...
#
#                               T14  T15
# 0  Herstellungsjahr, 1930er Jahre  NaN
# 1  Herstellungsjahr, 1930er Jahre  NaN
# 2  Herstellungsjahr, 1930er Jahre  NaN
# 3  Herstellungsjahr, 1930er Jahre  NaN
# 4  Herstellungsjahr, 1930er Jahre  NaN
#
# [5 rows x 84 columns]
